# %% [markdown]
# # Comunicação com Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Bibliotecas

# %%
import numpy as np
import cv2 as cv
from skimage import io
import os
import pandas as pd

# %%
def extract_feature_dataset(path, extractor='color'):
  images_path = os.listdir(path)
  category = os.path.basename(os.path.normpath(path))
  data = []
  images_name = []
  categories = []
  for n, image in enumerate(images_path):
    category = os.path.basename(os.path.normpath(path))
    img_name = category + image
    print('Extraindo: ', image, ' Category:', category, ' Quantidade: ', n, '/', len(images_path))
    image = cv.imread(os.path.join(path, image))
    image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    image_gray = cv.cvtColor(image, cv.COLOR_RGB2GRAY)

    features = []
    if extractor == 'color':
      dataset_hist_r = []
      dataset_hist_g = []
      dataset_hist_b = []

      color = ('r', 'g', 'b')
      counter = 0
      hist = {}
      for i, col in enumerate(color):
        histr = cv.calcHist([image_rgb], [i], None, [256], [0,256])
        if col == 'g':  
          dataset_hist_g.append(histr)
        if col == 'b':  
          dataset_hist_b.append(histr)
        if col == 'r':
          dataset_hist_r.append(histr)
          
      X_r = np.array(dataset_hist_r)
      length = np.sqrt((X_r**2).sum(axis=1))[:, None]
      X_r = X_r / length

      X_g = np.array(dataset_hist_g)
      length = np.sqrt((X_g**2).sum(axis=1))[:, None]
      X_g = X_g / length

      X_b = np.array(dataset_hist_b)
      length = np.sqrt((X_b**2).sum(axis=1))[:, None]
      X_b = X_b / length


      X = np.concatenate((X_r, X_g, X_b), axis=1)
      X.shape
      features = X.max(2)
    elif extractor == 'gray':
      histr = cv.calcHist([image_gray], [0], None, [32], [0,256])
      features = (histr).max(1)

    images_name.append(img_name)
    categories.append(category)
    features = np.append(features, category)
    data.append((features))
  return data, images_name

# %%
dataset_path = "DATASET PATH"
dataset_class = images_path = os.listdir(dataset_path)

paths = []

for index, value in enumerate(dataset_class):
  paths.append(os.path.join(dataset_path, value))

dataset = []
dataset_files = []
dataset_categories = []
for index, value in enumerate(paths):
  (extractions, files) = extract_feature_dataset(paths[index], extractor='gray')
  dataset = dataset + extractions
  dataset_files = dataset_files + files

print(dataset_categories)
df_data = pd.DataFrame(dataset)
# Out:
# Extraindo:  3.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  0 / 100
# Extraindo:  6.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  1 / 100
# Extraindo:  9.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  2 / 100
# Extraindo:  2.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  3 / 100
# Extraindo:  1.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  4 / 100
# Extraindo:  4.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  5 / 100
# Extraindo:  5.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  6 / 100
# Extraindo:  8.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  7 / 100
# Extraindo:  0.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  8 / 100
# Extraindo:  7.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  9 / 100
# Extraindo:  62.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  10 / 100
# Extraindo:  53.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  11 / 100
# Extraindo:  68.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  12 / 100
# Extraindo:  67.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  13 / 100
# Extraindo:  58.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  14 / 100
# Extraindo:  52.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  15 / 100
# Extraindo:  64.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  16 / 100
# Extraindo:  55.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  17 / 100
# Extraindo:  77.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  18 / 100
# Extraindo:  61.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  19 / 100
# Extraindo:  73.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  20 / 100
# Extraindo:  47.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  21 / 100
# Extraindo:  49.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  22 / 100
# Extraindo:  48.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  23 / 100
# Extraindo:  42.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  24 / 100
# Extraindo:  71.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  25 / 100
# Extraindo:  88.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  26 / 100
# Extraindo:  56.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  27 / 100
# Extraindo:  17.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  28 / 100
# Extraindo:  10.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  29 / 100
# Extraindo:  13.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  30 / 100
# Extraindo:  92.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  31 / 100
# Extraindo:  32.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  32 / 100
# Extraindo:  65.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  33 / 100
# Extraindo:  19.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  34 / 100
# Extraindo:  50.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  35 / 100
# Extraindo:  27.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  36 / 100
# Extraindo:  15.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  37 / 100
# Extraindo:  81.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  38 / 100
# Extraindo:  98.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  39 / 100
# Extraindo:  95.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  40 / 100
# Extraindo:  78.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  41 / 100
# Extraindo:  18.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  42 / 100
# Extraindo:  94.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  43 / 100
# Extraindo:  40.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  44 / 100
# Extraindo:  43.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  45 / 100
# Extraindo:  93.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  46 / 100
# Extraindo:  31.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  47 / 100
# Extraindo:  44.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  48 / 100
# Extraindo:  54.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  49 / 100
# Extraindo:  59.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  50 / 100
# Extraindo:  57.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  51 / 100
# Extraindo:  70.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  52 / 100
# Extraindo:  25.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  53 / 100
# Extraindo:  23.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  54 / 100
# Extraindo:  51.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  55 / 100
# Extraindo:  60.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  56 / 100
# Extraindo:  22.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  57 / 100
# Extraindo:  83.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  58 / 100
# Extraindo:  28.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  59 / 100
# Extraindo:  29.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  60 / 100
# Extraindo:  30.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  61 / 100
# Extraindo:  90.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  62 / 100
# Extraindo:  99.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  63 / 100
# Extraindo:  76.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  64 / 100
# Extraindo:  37.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  65 / 100
# Extraindo:  38.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  66 / 100
# Extraindo:  12.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  67 / 100
# Extraindo:  96.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  68 / 100
# Extraindo:  46.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  69 / 100
# Extraindo:  75.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  70 / 100
# Extraindo:  74.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  71 / 100
# Extraindo:  85.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  72 / 100
# Extraindo:  84.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  73 / 100
# Extraindo:  72.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  74 / 100
# Extraindo:  34.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  75 / 100
# Extraindo:  35.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  76 / 100
# Extraindo:  20.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  77 / 100
# Extraindo:  39.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  78 / 100
# Extraindo:  24.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  79 / 100
# Extraindo:  36.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  80 / 100
# Extraindo:  80.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  81 / 100
# Extraindo:  82.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  82 / 100
# Extraindo:  86.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  83 / 100
# Extraindo:  16.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  84 / 100
# Extraindo:  21.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  85 / 100
# Extraindo:  69.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  86 / 100
# Extraindo:  91.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  87 / 100
# Extraindo:  33.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  88 / 100
# Extraindo:  63.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  89 / 100
# Extraindo:  79.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  90 / 100
# Extraindo:  97.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  91 / 100
# Extraindo:  66.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  92 / 100
# Extraindo:  41.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  93 / 100
# Extraindo:  14.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  94 / 100
# Extraindo:  11.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  95 / 100
# Extraindo:  89.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  96 / 100
# Extraindo:  26.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  97 / 100
# Extraindo:  45.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  98 / 100
# Extraindo:  87.jpg  Category: peolpe_and_villages_in_Africa  Quantidade:  99 / 100
# Extraindo:  605.jpg  Category: flowers  Quantidade:  0 / 100
# Extraindo:  602.jpg  Category: flowers  Quantidade:  1 / 100
# Extraindo:  604.jpg  Category: flowers  Quantidade:  2 / 100
# Extraindo:  609.jpg  Category: flowers  Quantidade:  3 / 100
# Extraindo:  603.jpg  Category: flowers  Quantidade:  4 / 100
# Extraindo:  601.jpg  Category: flowers  Quantidade:  5 / 100
# Extraindo:  600.jpg  Category: flowers  Quantidade:  6 / 100
# Extraindo:  608.jpg  Category: flowers  Quantidade:  7 / 100
# Extraindo:  607.jpg  Category: flowers  Quantidade:  8 / 100
# Extraindo:  606.jpg  Category: flowers  Quantidade:  9 / 100
# Extraindo:  679.jpg  Category: flowers  Quantidade:  10 / 100
# Extraindo:  660.jpg  Category: flowers  Quantidade:  11 / 100
# Extraindo:  638.jpg  Category: flowers  Quantidade:  12 / 100
# Extraindo:  624.jpg  Category: flowers  Quantidade:  13 / 100
# Extraindo:  631.jpg  Category: flowers  Quantidade:  14 / 100
# Extraindo:  669.jpg  Category: flowers  Quantidade:  15 / 100
# Extraindo:  628.jpg  Category: flowers  Quantidade:  16 / 100
# Extraindo:  663.jpg  Category: flowers  Quantidade:  17 / 100
# Extraindo:  686.jpg  Category: flowers  Quantidade:  18 / 100
# Extraindo:  632.jpg  Category: flowers  Quantidade:  19 / 100
# Extraindo:  667.jpg  Category: flowers  Quantidade:  20 / 100
# Extraindo:  644.jpg  Category: flowers  Quantidade:  21 / 100
# Extraindo:  676.jpg  Category: flowers  Quantidade:  22 / 100
# Extraindo:  611.jpg  Category: flowers  Quantidade:  23 / 100
# Extraindo:  617.jpg  Category: flowers  Quantidade:  24 / 100
# Extraindo:  636.jpg  Category: flowers  Quantidade:  25 / 100
# Extraindo:  694.jpg  Category: flowers  Quantidade:  26 / 100
# Extraindo:  626.jpg  Category: flowers  Quantidade:  27 / 100
# Extraindo:  620.jpg  Category: flowers  Quantidade:  28 / 100
# Extraindo:  685.jpg  Category: flowers  Quantidade:  29 / 100
# Extraindo:  666.jpg  Category: flowers  Quantidade:  30 / 100
# Extraindo:  689.jpg  Category: flowers  Quantidade:  31 / 100
# Extraindo:  699.jpg  Category: flowers  Quantidade:  32 / 100
# Extraindo:  670.jpg  Category: flowers  Quantidade:  33 / 100
# Extraindo:  698.jpg  Category: flowers  Quantidade:  34 / 100
# Extraindo:  672.jpg  Category: flowers  Quantidade:  35 / 100
# Extraindo:  662.jpg  Category: flowers  Quantidade:  36 / 100
# Extraindo:  668.jpg  Category: flowers  Quantidade:  37 / 100
# Extraindo:  675.jpg  Category: flowers  Quantidade:  38 / 100
# Extraindo:  688.jpg  Category: flowers  Quantidade:  39 / 100
# Extraindo:  625.jpg  Category: flowers  Quantidade:  40 / 100
# Extraindo:  661.jpg  Category: flowers  Quantidade:  41 / 100
# Extraindo:  627.jpg  Category: flowers  Quantidade:  42 / 100
# Extraindo:  616.jpg  Category: flowers  Quantidade:  43 / 100
# Extraindo:  655.jpg  Category: flowers  Quantidade:  44 / 100
# Extraindo:  623.jpg  Category: flowers  Quantidade:  45 / 100
# Extraindo:  684.jpg  Category: flowers  Quantidade:  46 / 100
# Extraindo:  643.jpg  Category: flowers  Quantidade:  47 / 100
# Extraindo:  683.jpg  Category: flowers  Quantidade:  48 / 100
# Extraindo:  642.jpg  Category: flowers  Quantidade:  49 / 100
# Extraindo:  615.jpg  Category: flowers  Quantidade:  50 / 100
# Extraindo:  651.jpg  Category: flowers  Quantidade:  51 / 100
# Extraindo:  653.jpg  Category: flowers  Quantidade:  52 / 100
# Extraindo:  610.jpg  Category: flowers  Quantidade:  53 / 100
# Extraindo:  629.jpg  Category: flowers  Quantidade:  54 / 100
# Extraindo:  664.jpg  Category: flowers  Quantidade:  55 / 100
# Extraindo:  697.jpg  Category: flowers  Quantidade:  56 / 100
# Extraindo:  621.jpg  Category: flowers  Quantidade:  57 / 100
# Extraindo:  635.jpg  Category: flowers  Quantidade:  58 / 100
# Extraindo:  656.jpg  Category: flowers  Quantidade:  59 / 100
# Extraindo:  647.jpg  Category: flowers  Quantidade:  60 / 100
# Extraindo:  654.jpg  Category: flowers  Quantidade:  61 / 100
# Extraindo:  614.jpg  Category: flowers  Quantidade:  62 / 100
# Extraindo:  673.jpg  Category: flowers  Quantidade:  63 / 100
# Extraindo:  678.jpg  Category: flowers  Quantidade:  64 / 100
# Extraindo:  633.jpg  Category: flowers  Quantidade:  65 / 100
# Extraindo:  645.jpg  Category: flowers  Quantidade:  66 / 100
# Extraindo:  665.jpg  Category: flowers  Quantidade:  67 / 100
# Extraindo:  677.jpg  Category: flowers  Quantidade:  68 / 100
# Extraindo:  696.jpg  Category: flowers  Quantidade:  69 / 100
# Extraindo:  612.jpg  Category: flowers  Quantidade:  70 / 100
# Extraindo:  674.jpg  Category: flowers  Quantidade:  71 / 100
# Extraindo:  692.jpg  Category: flowers  Quantidade:  72 / 100
# Extraindo:  648.jpg  Category: flowers  Quantidade:  73 / 100
# Extraindo:  641.jpg  Category: flowers  Quantidade:  74 / 100
# Extraindo:  649.jpg  Category: flowers  Quantidade:  75 / 100
# Extraindo:  613.jpg  Category: flowers  Quantidade:  76 / 100
# Extraindo:  658.jpg  Category: flowers  Quantidade:  77 / 100
# Extraindo:  637.jpg  Category: flowers  Quantidade:  78 / 100
# Extraindo:  630.jpg  Category: flowers  Quantidade:  79 / 100
# Extraindo:  650.jpg  Category: flowers  Quantidade:  80 / 100
# Extraindo:  640.jpg  Category: flowers  Quantidade:  81 / 100
# Extraindo:  695.jpg  Category: flowers  Quantidade:  82 / 100
# Extraindo:  687.jpg  Category: flowers  Quantidade:  83 / 100
# Extraindo:  657.jpg  Category: flowers  Quantidade:  84 / 100
# Extraindo:  634.jpg  Category: flowers  Quantidade:  85 / 100
# Extraindo:  652.jpg  Category: flowers  Quantidade:  86 / 100
# Extraindo:  622.jpg  Category: flowers  Quantidade:  87 / 100
# Extraindo:  680.jpg  Category: flowers  Quantidade:  88 / 100
# Extraindo:  618.jpg  Category: flowers  Quantidade:  89 / 100
# Extraindo:  639.jpg  Category: flowers  Quantidade:  90 / 100
# Extraindo:  671.jpg  Category: flowers  Quantidade:  91 / 100
# Extraindo:  619.jpg  Category: flowers  Quantidade:  92 / 100
# Extraindo:  659.jpg  Category: flowers  Quantidade:  93 / 100
# Extraindo:  646.jpg  Category: flowers  Quantidade:  94 / 100
# Extraindo:  690.jpg  Category: flowers  Quantidade:  95 / 100
# Extraindo:  691.jpg  Category: flowers  Quantidade:  96 / 100
# Extraindo:  681.jpg  Category: flowers  Quantidade:  97 / 100
# Extraindo:  693.jpg  Category: flowers  Quantidade:  98 / 100
# Extraindo:  682.jpg  Category: flowers  Quantidade:  99 / 100
# Extraindo:  805.jpg  Category: mountains_and_snow  Quantidade:  0 / 100
# Extraindo:  808.jpg  Category: mountains_and_snow  Quantidade:  1 / 100
# Extraindo:  806.jpg  Category: mountains_and_snow  Quantidade:  2 / 100
# Extraindo:  801.jpg  Category: mountains_and_snow  Quantidade:  3 / 100
# Extraindo:  800.jpg  Category: mountains_and_snow  Quantidade:  4 / 100
# Extraindo:  807.jpg  Category: mountains_and_snow  Quantidade:  5 / 100
# Extraindo:  802.jpg  Category: mountains_and_snow  Quantidade:  6 / 100
# Extraindo:  809.jpg  Category: mountains_and_snow  Quantidade:  7 / 100
# Extraindo:  803.jpg  Category: mountains_and_snow  Quantidade:  8 / 100
# Extraindo:  804.jpg  Category: mountains_and_snow  Quantidade:  9 / 100
# Extraindo:  850.jpg  Category: mountains_and_snow  Quantidade:  10 / 100
# Extraindo:  890.jpg  Category: mountains_and_snow  Quantidade:  11 / 100
# Extraindo:  878.jpg  Category: mountains_and_snow  Quantidade:  12 / 100
# Extraindo:  852.jpg  Category: mountains_and_snow  Quantidade:  13 / 100
# Extraindo:  871.jpg  Category: mountains_and_snow  Quantidade:  14 / 100
# Extraindo:  836.jpg  Category: mountains_and_snow  Quantidade:  15 / 100
# Extraindo:  851.jpg  Category: mountains_and_snow  Quantidade:  16 / 100
# Extraindo:  840.jpg  Category: mountains_and_snow  Quantidade:  17 / 100
# Extraindo:  843.jpg  Category: mountains_and_snow  Quantidade:  18 / 100
# Extraindo:  895.jpg  Category: mountains_and_snow  Quantidade:  19 / 100
# Extraindo:  856.jpg  Category: mountains_and_snow  Quantidade:  20 / 100
# Extraindo:  821.jpg  Category: mountains_and_snow  Quantidade:  21 / 100
# Extraindo:  831.jpg  Category: mountains_and_snow  Quantidade:  22 / 100
# Extraindo:  889.jpg  Category: mountains_and_snow  Quantidade:  23 / 100
# Extraindo:  870.jpg  Category: mountains_and_snow  Quantidade:  24 / 100
# Extraindo:  894.jpg  Category: mountains_and_snow  Quantidade:  25 / 100
# Extraindo:  841.jpg  Category: mountains_and_snow  Quantidade:  26 / 100
# Extraindo:  839.jpg  Category: mountains_and_snow  Quantidade:  27 / 100
# Extraindo:  811.jpg  Category: mountains_and_snow  Quantidade:  28 / 100
# Extraindo:  824.jpg  Category: mountains_and_snow  Quantidade:  29 / 100
# Extraindo:  842.jpg  Category: mountains_and_snow  Quantidade:  30 / 100
# Extraindo:  838.jpg  Category: mountains_and_snow  Quantidade:  31 / 100
# Extraindo:  885.jpg  Category: mountains_and_snow  Quantidade:  32 / 100
# Extraindo:  810.jpg  Category: mountains_and_snow  Quantidade:  33 / 100
# Extraindo:  845.jpg  Category: mountains_and_snow  Quantidade:  34 / 100
# Extraindo:  884.jpg  Category: mountains_and_snow  Quantidade:  35 / 100
# Extraindo:  817.jpg  Category: mountains_and_snow  Quantidade:  36 / 100
# Extraindo:  865.jpg  Category: mountains_and_snow  Quantidade:  37 / 100
# Extraindo:  847.jpg  Category: mountains_and_snow  Quantidade:  38 / 100
# Extraindo:  873.jpg  Category: mountains_and_snow  Quantidade:  39 / 100
# Extraindo:  830.jpg  Category: mountains_and_snow  Quantidade:  40 / 100
# Extraindo:  898.jpg  Category: mountains_and_snow  Quantidade:  41 / 100
# Extraindo:  816.jpg  Category: mountains_and_snow  Quantidade:  42 / 100
# Extraindo:  899.jpg  Category: mountains_and_snow  Quantidade:  43 / 100
# Extraindo:  883.jpg  Category: mountains_and_snow  Quantidade:  44 / 100
# Extraindo:  867.jpg  Category: mountains_and_snow  Quantidade:  45 / 100
# Extraindo:  859.jpg  Category: mountains_and_snow  Quantidade:  46 / 100
# Extraindo:  864.jpg  Category: mountains_and_snow  Quantidade:  47 / 100
# Extraindo:  862.jpg  Category: mountains_and_snow  Quantidade:  48 / 100
# Extraindo:  855.jpg  Category: mountains_and_snow  Quantidade:  49 / 100
# Extraindo:  837.jpg  Category: mountains_and_snow  Quantidade:  50 / 100
# Extraindo:  823.jpg  Category: mountains_and_snow  Quantidade:  51 / 100
# Extraindo:  876.jpg  Category: mountains_and_snow  Quantidade:  52 / 100
# Extraindo:  874.jpg  Category: mountains_and_snow  Quantidade:  53 / 100
# Extraindo:  854.jpg  Category: mountains_and_snow  Quantidade:  54 / 100
# Extraindo:  887.jpg  Category: mountains_and_snow  Quantidade:  55 / 100
# Extraindo:  818.jpg  Category: mountains_and_snow  Quantidade:  56 / 100
# Extraindo:  834.jpg  Category: mountains_and_snow  Quantidade:  57 / 100
# Extraindo:  844.jpg  Category: mountains_and_snow  Quantidade:  58 / 100
# Extraindo:  822.jpg  Category: mountains_and_snow  Quantidade:  59 / 100
# Extraindo:  825.jpg  Category: mountains_and_snow  Quantidade:  60 / 100
# Extraindo:  866.jpg  Category: mountains_and_snow  Quantidade:  61 / 100
# Extraindo:  857.jpg  Category: mountains_and_snow  Quantidade:  62 / 100
# Extraindo:  829.jpg  Category: mountains_and_snow  Quantidade:  63 / 100
# Extraindo:  861.jpg  Category: mountains_and_snow  Quantidade:  64 / 100
# Extraindo:  875.jpg  Category: mountains_and_snow  Quantidade:  65 / 100
# Extraindo:  828.jpg  Category: mountains_and_snow  Quantidade:  66 / 100
# Extraindo:  820.jpg  Category: mountains_and_snow  Quantidade:  67 / 100
# Extraindo:  886.jpg  Category: mountains_and_snow  Quantidade:  68 / 100
# Extraindo:  819.jpg  Category: mountains_and_snow  Quantidade:  69 / 100
# Extraindo:  863.jpg  Category: mountains_and_snow  Quantidade:  70 / 100
# Extraindo:  893.jpg  Category: mountains_and_snow  Quantidade:  71 / 100
# Extraindo:  881.jpg  Category: mountains_and_snow  Quantidade:  72 / 100
# Extraindo:  879.jpg  Category: mountains_and_snow  Quantidade:  73 / 100
# Extraindo:  888.jpg  Category: mountains_and_snow  Quantidade:  74 / 100
# Extraindo:  832.jpg  Category: mountains_and_snow  Quantidade:  75 / 100
# Extraindo:  814.jpg  Category: mountains_and_snow  Quantidade:  76 / 100
# Extraindo:  869.jpg  Category: mountains_and_snow  Quantidade:  77 / 100
# Extraindo:  846.jpg  Category: mountains_and_snow  Quantidade:  78 / 100
# Extraindo:  835.jpg  Category: mountains_and_snow  Quantidade:  79 / 100
# Extraindo:  858.jpg  Category: mountains_and_snow  Quantidade:  80 / 100
# Extraindo:  880.jpg  Category: mountains_and_snow  Quantidade:  81 / 100
# Extraindo:  860.jpg  Category: mountains_and_snow  Quantidade:  82 / 100
# Extraindo:  872.jpg  Category: mountains_and_snow  Quantidade:  83 / 100
# Extraindo:  827.jpg  Category: mountains_and_snow  Quantidade:  84 / 100
# Extraindo:  891.jpg  Category: mountains_and_snow  Quantidade:  85 / 100
# Extraindo:  868.jpg  Category: mountains_and_snow  Quantidade:  86 / 100
# Extraindo:  882.jpg  Category: mountains_and_snow  Quantidade:  87 / 100
# Extraindo:  896.jpg  Category: mountains_and_snow  Quantidade:  88 / 100
# Extraindo:  812.jpg  Category: mountains_and_snow  Quantidade:  89 / 100
# Extraindo:  877.jpg  Category: mountains_and_snow  Quantidade:  90 / 100
# Extraindo:  853.jpg  Category: mountains_and_snow  Quantidade:  91 / 100
# Extraindo:  815.jpg  Category: mountains_and_snow  Quantidade:  92 / 100
# Extraindo:  833.jpg  Category: mountains_and_snow  Quantidade:  93 / 100
# Extraindo:  848.jpg  Category: mountains_and_snow  Quantidade:  94 / 100
# Extraindo:  892.jpg  Category: mountains_and_snow  Quantidade:  95 / 100
# Extraindo:  826.jpg  Category: mountains_and_snow  Quantidade:  96 / 100
# Extraindo:  849.jpg  Category: mountains_and_snow  Quantidade:  97 / 100
# Extraindo:  897.jpg  Category: mountains_and_snow  Quantidade:  98 / 100
# Extraindo:  813.jpg  Category: mountains_and_snow  Quantidade:  99 / 100
# Extraindo:  208.jpg  Category: monuments  Quantidade:  0 / 100
# Extraindo:  201.jpg  Category: monuments  Quantidade:  1 / 100
# Extraindo:  205.jpg  Category: monuments  Quantidade:  2 / 100
# Extraindo:  204.jpg  Category: monuments  Quantidade:  3 / 100
# Extraindo:  203.jpg  Category: monuments  Quantidade:  4 / 100
# Extraindo:  200.jpg  Category: monuments  Quantidade:  5 / 100
# Extraindo:  207.jpg  Category: monuments  Quantidade:  6 / 100
# Extraindo:  209.jpg  Category: monuments  Quantidade:  7 / 100
# Extraindo:  202.jpg  Category: monuments  Quantidade:  8 / 100
# Extraindo:  206.jpg  Category: monuments  Quantidade:  9 / 100
# Extraindo:  274.jpg  Category: monuments  Quantidade:  10 / 100
# Extraindo:  259.jpg  Category: monuments  Quantidade:  11 / 100
# Extraindo:  251.jpg  Category: monuments  Quantidade:  12 / 100
# Extraindo:  286.jpg  Category: monuments  Quantidade:  13 / 100
# Extraindo:  248.jpg  Category: monuments  Quantidade:  14 / 100
# Extraindo:  214.jpg  Category: monuments  Quantidade:  15 / 100
# Extraindo:  235.jpg  Category: monuments  Quantidade:  16 / 100
# Extraindo:  234.jpg  Category: monuments  Quantidade:  17 / 100
# Extraindo:  213.jpg  Category: monuments  Quantidade:  18 / 100
# Extraindo:  233.jpg  Category: monuments  Quantidade:  19 / 100
# Extraindo:  270.jpg  Category: monuments  Quantidade:  20 / 100
# Extraindo:  212.jpg  Category: monuments  Quantidade:  21 / 100
# Extraindo:  246.jpg  Category: monuments  Quantidade:  22 / 100
# Extraindo:  281.jpg  Category: monuments  Quantidade:  23 / 100
# Extraindo:  220.jpg  Category: monuments  Quantidade:  24 / 100
# Extraindo:  288.jpg  Category: monuments  Quantidade:  25 / 100
# Extraindo:  238.jpg  Category: monuments  Quantidade:  26 / 100
# Extraindo:  273.jpg  Category: monuments  Quantidade:  27 / 100
# Extraindo:  293.jpg  Category: monuments  Quantidade:  28 / 100
# Extraindo:  255.jpg  Category: monuments  Quantidade:  29 / 100
# Extraindo:  226.jpg  Category: monuments  Quantidade:  30 / 100
# Extraindo:  278.jpg  Category: monuments  Quantidade:  31 / 100
# Extraindo:  229.jpg  Category: monuments  Quantidade:  32 / 100
# Extraindo:  269.jpg  Category: monuments  Quantidade:  33 / 100
# Extraindo:  271.jpg  Category: monuments  Quantidade:  34 / 100
# Extraindo:  261.jpg  Category: monuments  Quantidade:  35 / 100
# Extraindo:  210.jpg  Category: monuments  Quantidade:  36 / 100
# Extraindo:  295.jpg  Category: monuments  Quantidade:  37 / 100
# Extraindo:  237.jpg  Category: monuments  Quantidade:  38 / 100
# Extraindo:  228.jpg  Category: monuments  Quantidade:  39 / 100
# Extraindo:  284.jpg  Category: monuments  Quantidade:  40 / 100
# Extraindo:  292.jpg  Category: monuments  Quantidade:  41 / 100
# Extraindo:  253.jpg  Category: monuments  Quantidade:  42 / 100
# Extraindo:  260.jpg  Category: monuments  Quantidade:  43 / 100
# Extraindo:  266.jpg  Category: monuments  Quantidade:  44 / 100
# Extraindo:  280.jpg  Category: monuments  Quantidade:  45 / 100
# Extraindo:  296.jpg  Category: monuments  Quantidade:  46 / 100
# Extraindo:  287.jpg  Category: monuments  Quantidade:  47 / 100
# Extraindo:  230.jpg  Category: monuments  Quantidade:  48 / 100
# Extraindo:  247.jpg  Category: monuments  Quantidade:  49 / 100
# Extraindo:  252.jpg  Category: monuments  Quantidade:  50 / 100
# Extraindo:  285.jpg  Category: monuments  Quantidade:  51 / 100
# Extraindo:  291.jpg  Category: monuments  Quantidade:  52 / 100
# Extraindo:  245.jpg  Category: monuments  Quantidade:  53 / 100
# Extraindo:  221.jpg  Category: monuments  Quantidade:  54 / 100
# Extraindo:  257.jpg  Category: monuments  Quantidade:  55 / 100
# Extraindo:  227.jpg  Category: monuments  Quantidade:  56 / 100
# Extraindo:  224.jpg  Category: monuments  Quantidade:  57 / 100
# Extraindo:  289.jpg  Category: monuments  Quantidade:  58 / 100
# Extraindo:  262.jpg  Category: monuments  Quantidade:  59 / 100
# Extraindo:  242.jpg  Category: monuments  Quantidade:  60 / 100
# Extraindo:  222.jpg  Category: monuments  Quantidade:  61 / 100
# Extraindo:  211.jpg  Category: monuments  Quantidade:  62 / 100
# Extraindo:  297.jpg  Category: monuments  Quantidade:  63 / 100
# Extraindo:  268.jpg  Category: monuments  Quantidade:  64 / 100
# Extraindo:  219.jpg  Category: monuments  Quantidade:  65 / 100
# Extraindo:  223.jpg  Category: monuments  Quantidade:  66 / 100
# Extraindo:  272.jpg  Category: monuments  Quantidade:  67 / 100
# Extraindo:  277.jpg  Category: monuments  Quantidade:  68 / 100
# Extraindo:  225.jpg  Category: monuments  Quantidade:  69 / 100
# Extraindo:  264.jpg  Category: monuments  Quantidade:  70 / 100
# Extraindo:  215.jpg  Category: monuments  Quantidade:  71 / 100
# Extraindo:  298.jpg  Category: monuments  Quantidade:  72 / 100
# Extraindo:  231.jpg  Category: monuments  Quantidade:  73 / 100
# Extraindo:  282.jpg  Category: monuments  Quantidade:  74 / 100
# Extraindo:  299.jpg  Category: monuments  Quantidade:  75 / 100
# Extraindo:  241.jpg  Category: monuments  Quantidade:  76 / 100
# Extraindo:  240.jpg  Category: monuments  Quantidade:  77 / 100
# Extraindo:  256.jpg  Category: monuments  Quantidade:  78 / 100
# Extraindo:  283.jpg  Category: monuments  Quantidade:  79 / 100
# Extraindo:  276.jpg  Category: monuments  Quantidade:  80 / 100
# Extraindo:  239.jpg  Category: monuments  Quantidade:  81 / 100
# Extraindo:  265.jpg  Category: monuments  Quantidade:  82 / 100
# Extraindo:  243.jpg  Category: monuments  Quantidade:  83 / 100
# Extraindo:  232.jpg  Category: monuments  Quantidade:  84 / 100
# Extraindo:  218.jpg  Category: monuments  Quantidade:  85 / 100
# Extraindo:  263.jpg  Category: monuments  Quantidade:  86 / 100
# Extraindo:  217.jpg  Category: monuments  Quantidade:  87 / 100
# Extraindo:  275.jpg  Category: monuments  Quantidade:  88 / 100
# Extraindo:  250.jpg  Category: monuments  Quantidade:  89 / 100
# Extraindo:  216.jpg  Category: monuments  Quantidade:  90 / 100
# Extraindo:  258.jpg  Category: monuments  Quantidade:  91 / 100
# Extraindo:  244.jpg  Category: monuments  Quantidade:  92 / 100
# Extraindo:  290.jpg  Category: monuments  Quantidade:  93 / 100
# Extraindo:  236.jpg  Category: monuments  Quantidade:  94 / 100
# Extraindo:  249.jpg  Category: monuments  Quantidade:  95 / 100
# Extraindo:  279.jpg  Category: monuments  Quantidade:  96 / 100
# Extraindo:  294.jpg  Category: monuments  Quantidade:  97 / 100
# Extraindo:  254.jpg  Category: monuments  Quantidade:  98 / 100
# Extraindo:  267.jpg  Category: monuments  Quantidade:  99 / 100
# Extraindo:  903.jpg  Category: foods  Quantidade:  0 / 100
# Extraindo:  908.jpg  Category: foods  Quantidade:  1 / 100
# Extraindo:  902.jpg  Category: foods  Quantidade:  2 / 100
# Extraindo:  900.jpg  Category: foods  Quantidade:  3 / 100
# Extraindo:  906.jpg  Category: foods  Quantidade:  4 / 100
# Extraindo:  909.jpg  Category: foods  Quantidade:  5 / 100
# Extraindo:  905.jpg  Category: foods  Quantidade:  6 / 100
# Extraindo:  901.jpg  Category: foods  Quantidade:  7 / 100
# Extraindo:  904.jpg  Category: foods  Quantidade:  8 / 100
# Extraindo:  907.jpg  Category: foods  Quantidade:  9 / 100
# Extraindo:  943.jpg  Category: foods  Quantidade:  10 / 100
# Extraindo:  955.jpg  Category: foods  Quantidade:  11 / 100
# Extraindo:  966.jpg  Category: foods  Quantidade:  12 / 100
# Extraindo:  997.jpg  Category: foods  Quantidade:  13 / 100
# Extraindo:  969.jpg  Category: foods  Quantidade:  14 / 100
# Extraindo:  947.jpg  Category: foods  Quantidade:  15 / 100
# Extraindo:  977.jpg  Category: foods  Quantidade:  16 / 100
# Extraindo:  992.jpg  Category: foods  Quantidade:  17 / 100
# Extraindo:  950.jpg  Category: foods  Quantidade:  18 / 100
# Extraindo:  975.jpg  Category: foods  Quantidade:  19 / 100
# Extraindo:  934.jpg  Category: foods  Quantidade:  20 / 100
# Extraindo:  957.jpg  Category: foods  Quantidade:  21 / 100
# Extraindo:  972.jpg  Category: foods  Quantidade:  22 / 100
# Extraindo:  946.jpg  Category: foods  Quantidade:  23 / 100
# Extraindo:  932.jpg  Category: foods  Quantidade:  24 / 100
# Extraindo:  984.jpg  Category: foods  Quantidade:  25 / 100
# Extraindo:  974.jpg  Category: foods  Quantidade:  26 / 100
# Extraindo:  952.jpg  Category: foods  Quantidade:  27 / 100
# Extraindo:  981.jpg  Category: foods  Quantidade:  28 / 100
# Extraindo:  953.jpg  Category: foods  Quantidade:  29 / 100
# Extraindo:  944.jpg  Category: foods  Quantidade:  30 / 100
# Extraindo:  914.jpg  Category: foods  Quantidade:  31 / 100
# Extraindo:  962.jpg  Category: foods  Quantidade:  32 / 100
# Extraindo:  951.jpg  Category: foods  Quantidade:  33 / 100
# Extraindo:  988.jpg  Category: foods  Quantidade:  34 / 100
# Extraindo:  996.jpg  Category: foods  Quantidade:  35 / 100
# Extraindo:  929.jpg  Category: foods  Quantidade:  36 / 100
# Extraindo:  995.jpg  Category: foods  Quantidade:  37 / 100
# Extraindo:  991.jpg  Category: foods  Quantidade:  38 / 100
# Extraindo:  937.jpg  Category: foods  Quantidade:  39 / 100
# Extraindo:  931.jpg  Category: foods  Quantidade:  40 / 100
# Extraindo:  961.jpg  Category: foods  Quantidade:  41 / 100
# Extraindo:  915.jpg  Category: foods  Quantidade:  42 / 100
# Extraindo:  933.jpg  Category: foods  Quantidade:  43 / 100
# Extraindo:  976.jpg  Category: foods  Quantidade:  44 / 100
# Extraindo:  923.jpg  Category: foods  Quantidade:  45 / 100
# Extraindo:  983.jpg  Category: foods  Quantidade:  46 / 100
# Extraindo:  973.jpg  Category: foods  Quantidade:  47 / 100
# Extraindo:  980.jpg  Category: foods  Quantidade:  48 / 100
# Extraindo:  945.jpg  Category: foods  Quantidade:  49 / 100
# Extraindo:  989.jpg  Category: foods  Quantidade:  50 / 100
# Extraindo:  919.jpg  Category: foods  Quantidade:  51 / 100
# Extraindo:  942.jpg  Category: foods  Quantidade:  52 / 100
# Extraindo:  939.jpg  Category: foods  Quantidade:  53 / 100
# Extraindo:  928.jpg  Category: foods  Quantidade:  54 / 100
# Extraindo:  925.jpg  Category: foods  Quantidade:  55 / 100
# Extraindo:  998.jpg  Category: foods  Quantidade:  56 / 100
# Extraindo:  924.jpg  Category: foods  Quantidade:  57 / 100
# Extraindo:  994.jpg  Category: foods  Quantidade:  58 / 100
# Extraindo:  982.jpg  Category: foods  Quantidade:  59 / 100
# Extraindo:  918.jpg  Category: foods  Quantidade:  60 / 100
# Extraindo:  954.jpg  Category: foods  Quantidade:  61 / 100
# Extraindo:  986.jpg  Category: foods  Quantidade:  62 / 100
# Extraindo:  917.jpg  Category: foods  Quantidade:  63 / 100
# Extraindo:  941.jpg  Category: foods  Quantidade:  64 / 100
# Extraindo:  963.jpg  Category: foods  Quantidade:  65 / 100
# Extraindo:  940.jpg  Category: foods  Quantidade:  66 / 100
# Extraindo:  971.jpg  Category: foods  Quantidade:  67 / 100
# Extraindo:  960.jpg  Category: foods  Quantidade:  68 / 100
# Extraindo:  948.jpg  Category: foods  Quantidade:  69 / 100
# Extraindo:  910.jpg  Category: foods  Quantidade:  70 / 100
# Extraindo:  970.jpg  Category: foods  Quantidade:  71 / 100
# Extraindo:  913.jpg  Category: foods  Quantidade:  72 / 100
# Extraindo:  965.jpg  Category: foods  Quantidade:  73 / 100
# Extraindo:  938.jpg  Category: foods  Quantidade:  74 / 100
# Extraindo:  968.jpg  Category: foods  Quantidade:  75 / 100
# Extraindo:  912.jpg  Category: foods  Quantidade:  76 / 100
# Extraindo:  993.jpg  Category: foods  Quantidade:  77 / 100
# Extraindo:  935.jpg  Category: foods  Quantidade:  78 / 100
# Extraindo:  936.jpg  Category: foods  Quantidade:  79 / 100
# Extraindo:  916.jpg  Category: foods  Quantidade:  80 / 100
# Extraindo:  964.jpg  Category: foods  Quantidade:  81 / 100
# Extraindo:  930.jpg  Category: foods  Quantidade:  82 / 100
# Extraindo:  920.jpg  Category: foods  Quantidade:  83 / 100
# Extraindo:  958.jpg  Category: foods  Quantidade:  84 / 100
# Extraindo:  921.jpg  Category: foods  Quantidade:  85 / 100
# Extraindo:  926.jpg  Category: foods  Quantidade:  86 / 100
# Extraindo:  990.jpg  Category: foods  Quantidade:  87 / 100
# Extraindo:  959.jpg  Category: foods  Quantidade:  88 / 100
# Extraindo:  922.jpg  Category: foods  Quantidade:  89 / 100
# Extraindo:  949.jpg  Category: foods  Quantidade:  90 / 100
# Extraindo:  979.jpg  Category: foods  Quantidade:  91 / 100
# Extraindo:  956.jpg  Category: foods  Quantidade:  92 / 100
# Extraindo:  985.jpg  Category: foods  Quantidade:  93 / 100
# Extraindo:  927.jpg  Category: foods  Quantidade:  94 / 100
# Extraindo:  987.jpg  Category: foods  Quantidade:  95 / 100
# Extraindo:  978.jpg  Category: foods  Quantidade:  96 / 100
# Extraindo:  911.jpg  Category: foods  Quantidade:  97 / 100
# Extraindo:  967.jpg  Category: foods  Quantidade:  98 / 100
# Extraindo:  999.jpg  Category: foods  Quantidade:  99 / 100
# Extraindo:  101.jpg  Category: beaches  Quantidade:  0 / 100
# Extraindo:  103.jpg  Category: beaches  Quantidade:  1 / 100
# Extraindo:  104.jpg  Category: beaches  Quantidade:  2 / 100
# Extraindo:  102.jpg  Category: beaches  Quantidade:  3 / 100
# Extraindo:  100.jpg  Category: beaches  Quantidade:  4 / 100
# Extraindo:  139.jpg  Category: beaches  Quantidade:  5 / 100
# Extraindo:  153.jpg  Category: beaches  Quantidade:  6 / 100
# Extraindo:  107.jpg  Category: beaches  Quantidade:  7 / 100
# Extraindo:  110.jpg  Category: beaches  Quantidade:  8 / 100
# Extraindo:  193.jpg  Category: beaches  Quantidade:  9 / 100
# Extraindo:  181.jpg  Category: beaches  Quantidade:  10 / 100
# Extraindo:  145.jpg  Category: beaches  Quantidade:  11 / 100
# Extraindo:  113.jpg  Category: beaches  Quantidade:  12 / 100
# Extraindo:  167.jpg  Category: beaches  Quantidade:  13 / 100
# Extraindo:  165.jpg  Category: beaches  Quantidade:  14 / 100
# Extraindo:  151.jpg  Category: beaches  Quantidade:  15 / 100
# Extraindo:  180.jpg  Category: beaches  Quantidade:  16 / 100
# Extraindo:  189.jpg  Category: beaches  Quantidade:  17 / 100
# Extraindo:  138.jpg  Category: beaches  Quantidade:  18 / 100
# Extraindo:  199.jpg  Category: beaches  Quantidade:  19 / 100
# Extraindo:  170.jpg  Category: beaches  Quantidade:  20 / 100
# Extraindo:  133.jpg  Category: beaches  Quantidade:  21 / 100
# Extraindo:  173.jpg  Category: beaches  Quantidade:  22 / 100
# Extraindo:  126.jpg  Category: beaches  Quantidade:  23 / 100
# Extraindo:  128.jpg  Category: beaches  Quantidade:  24 / 100
# Extraindo:  148.jpg  Category: beaches  Quantidade:  25 / 100
# Extraindo:  117.jpg  Category: beaches  Quantidade:  26 / 100
# Extraindo:  187.jpg  Category: beaches  Quantidade:  27 / 100
# Extraindo:  137.jpg  Category: beaches  Quantidade:  28 / 100
# Extraindo:  125.jpg  Category: beaches  Quantidade:  29 / 100
# Extraindo:  182.jpg  Category: beaches  Quantidade:  30 / 100
# Extraindo:  109.jpg  Category: beaches  Quantidade:  31 / 100
# Extraindo:  178.jpg  Category: beaches  Quantidade:  32 / 100
# Extraindo:  158.jpg  Category: beaches  Quantidade:  33 / 100
# Extraindo:  179.jpg  Category: beaches  Quantidade:  34 / 100
# Extraindo:  106.jpg  Category: beaches  Quantidade:  35 / 100
# Extraindo:  132.jpg  Category: beaches  Quantidade:  36 / 100
# Extraindo:  146.jpg  Category: beaches  Quantidade:  37 / 100
# Extraindo:  156.jpg  Category: beaches  Quantidade:  38 / 100
# Extraindo:  111.jpg  Category: beaches  Quantidade:  39 / 100
# Extraindo:  154.jpg  Category: beaches  Quantidade:  40 / 100
# Extraindo:  183.jpg  Category: beaches  Quantidade:  41 / 100
# Extraindo:  164.jpg  Category: beaches  Quantidade:  42 / 100
# Extraindo:  191.jpg  Category: beaches  Quantidade:  43 / 100
# Extraindo:  188.jpg  Category: beaches  Quantidade:  44 / 100
# Extraindo:  184.jpg  Category: beaches  Quantidade:  45 / 100
# Extraindo:  190.jpg  Category: beaches  Quantidade:  46 / 100
# Extraindo:  114.jpg  Category: beaches  Quantidade:  47 / 100
# Extraindo:  123.jpg  Category: beaches  Quantidade:  48 / 100
# Extraindo:  129.jpg  Category: beaches  Quantidade:  49 / 100
# Extraindo:  197.jpg  Category: beaches  Quantidade:  50 / 100
# Extraindo:  149.jpg  Category: beaches  Quantidade:  51 / 100
# Extraindo:  198.jpg  Category: beaches  Quantidade:  52 / 100
# Extraindo:  159.jpg  Category: beaches  Quantidade:  53 / 100
# Extraindo:  150.jpg  Category: beaches  Quantidade:  54 / 100
# Extraindo:  161.jpg  Category: beaches  Quantidade:  55 / 100
# Extraindo:  124.jpg  Category: beaches  Quantidade:  56 / 100
# Extraindo:  166.jpg  Category: beaches  Quantidade:  57 / 100
# Extraindo:  163.jpg  Category: beaches  Quantidade:  58 / 100
# Extraindo:  140.jpg  Category: beaches  Quantidade:  59 / 100
# Extraindo:  131.jpg  Category: beaches  Quantidade:  60 / 100
# Extraindo:  127.jpg  Category: beaches  Quantidade:  61 / 100
# Extraindo:  172.jpg  Category: beaches  Quantidade:  62 / 100
# Extraindo:  112.jpg  Category: beaches  Quantidade:  63 / 100
# Extraindo:  176.jpg  Category: beaches  Quantidade:  64 / 100
# Extraindo:  169.jpg  Category: beaches  Quantidade:  65 / 100
# Extraindo:  118.jpg  Category: beaches  Quantidade:  66 / 100
# Extraindo:  192.jpg  Category: beaches  Quantidade:  67 / 100
# Extraindo:  195.jpg  Category: beaches  Quantidade:  68 / 100
# Extraindo:  152.jpg  Category: beaches  Quantidade:  69 / 100
# Extraindo:  115.jpg  Category: beaches  Quantidade:  70 / 100
# Extraindo:  162.jpg  Category: beaches  Quantidade:  71 / 100
# Extraindo:  147.jpg  Category: beaches  Quantidade:  72 / 100
# Extraindo:  105.jpg  Category: beaches  Quantidade:  73 / 100
# Extraindo:  130.jpg  Category: beaches  Quantidade:  74 / 100
# Extraindo:  119.jpg  Category: beaches  Quantidade:  75 / 100
# Extraindo:  168.jpg  Category: beaches  Quantidade:  76 / 100
# Extraindo:  185.jpg  Category: beaches  Quantidade:  77 / 100
# Extraindo:  177.jpg  Category: beaches  Quantidade:  78 / 100
# Extraindo:  108.jpg  Category: beaches  Quantidade:  79 / 100
# Extraindo:  141.jpg  Category: beaches  Quantidade:  80 / 100
# Extraindo:  135.jpg  Category: beaches  Quantidade:  81 / 100
# Extraindo:  174.jpg  Category: beaches  Quantidade:  82 / 100
# Extraindo:  136.jpg  Category: beaches  Quantidade:  83 / 100
# Extraindo:  157.jpg  Category: beaches  Quantidade:  84 / 100
# Extraindo:  143.jpg  Category: beaches  Quantidade:  85 / 100
# Extraindo:  134.jpg  Category: beaches  Quantidade:  86 / 100
# Extraindo:  120.jpg  Category: beaches  Quantidade:  87 / 100
# Extraindo:  121.jpg  Category: beaches  Quantidade:  88 / 100
# Extraindo:  171.jpg  Category: beaches  Quantidade:  89 / 100
# Extraindo:  116.jpg  Category: beaches  Quantidade:  90 / 100
# Extraindo:  196.jpg  Category: beaches  Quantidade:  91 / 100
# Extraindo:  194.jpg  Category: beaches  Quantidade:  92 / 100
# Extraindo:  155.jpg  Category: beaches  Quantidade:  93 / 100
# Extraindo:  175.jpg  Category: beaches  Quantidade:  94 / 100
# Extraindo:  122.jpg  Category: beaches  Quantidade:  95 / 100
# Extraindo:  186.jpg  Category: beaches  Quantidade:  96 / 100
# Extraindo:  142.jpg  Category: beaches  Quantidade:  97 / 100
# Extraindo:  160.jpg  Category: beaches  Quantidade:  98 / 100
# Extraindo:  144.jpg  Category: beaches  Quantidade:  99 / 100
# Extraindo:  707.jpg  Category: horses  Quantidade:  0 / 100
# Extraindo:  709.jpg  Category: horses  Quantidade:  1 / 100
# Extraindo:  704.jpg  Category: horses  Quantidade:  2 / 100
# Extraindo:  705.jpg  Category: horses  Quantidade:  3 / 100
# Extraindo:  700.jpg  Category: horses  Quantidade:  4 / 100
# Extraindo:  702.jpg  Category: horses  Quantidade:  5 / 100
# Extraindo:  706.jpg  Category: horses  Quantidade:  6 / 100
# Extraindo:  708.jpg  Category: horses  Quantidade:  7 / 100
# Extraindo:  703.jpg  Category: horses  Quantidade:  8 / 100
# Extraindo:  701.jpg  Category: horses  Quantidade:  9 / 100
# Extraindo:  789.jpg  Category: horses  Quantidade:  10 / 100
# Extraindo:  771.jpg  Category: horses  Quantidade:  11 / 100
# Extraindo:  794.jpg  Category: horses  Quantidade:  12 / 100
# Extraindo:  791.jpg  Category: horses  Quantidade:  13 / 100
# Extraindo:  719.jpg  Category: horses  Quantidade:  14 / 100
# Extraindo:  736.jpg  Category: horses  Quantidade:  15 / 100
# Extraindo:  728.jpg  Category: horses  Quantidade:  16 / 100
# Extraindo:  795.jpg  Category: horses  Quantidade:  17 / 100
# Extraindo:  713.jpg  Category: horses  Quantidade:  18 / 100
# Extraindo:  758.jpg  Category: horses  Quantidade:  19 / 100
# Extraindo:  724.jpg  Category: horses  Quantidade:  20 / 100
# Extraindo:  723.jpg  Category: horses  Quantidade:  21 / 100
# Extraindo:  750.jpg  Category: horses  Quantidade:  22 / 100
# Extraindo:  757.jpg  Category: horses  Quantidade:  23 / 100
# Extraindo:  721.jpg  Category: horses  Quantidade:  24 / 100
# Extraindo:  755.jpg  Category: horses  Quantidade:  25 / 100
# Extraindo:  770.jpg  Category: horses  Quantidade:  26 / 100
# Extraindo:  752.jpg  Category: horses  Quantidade:  27 / 100
# Extraindo:  773.jpg  Category: horses  Quantidade:  28 / 100
# Extraindo:  769.jpg  Category: horses  Quantidade:  29 / 100
# Extraindo:  777.jpg  Category: horses  Quantidade:  30 / 100
# Extraindo:  740.jpg  Category: horses  Quantidade:  31 / 100
# Extraindo:  767.jpg  Category: horses  Quantidade:  32 / 100
# Extraindo:  797.jpg  Category: horses  Quantidade:  33 / 100
# Extraindo:  711.jpg  Category: horses  Quantidade:  34 / 100
# Extraindo:  761.jpg  Category: horses  Quantidade:  35 / 100
# Extraindo:  760.jpg  Category: horses  Quantidade:  36 / 100
# Extraindo:  762.jpg  Category: horses  Quantidade:  37 / 100
# Extraindo:  717.jpg  Category: horses  Quantidade:  38 / 100
# Extraindo:  786.jpg  Category: horses  Quantidade:  39 / 100
# Extraindo:  784.jpg  Category: horses  Quantidade:  40 / 100
# Extraindo:  722.jpg  Category: horses  Quantidade:  41 / 100
# Extraindo:  774.jpg  Category: horses  Quantidade:  42 / 100
# Extraindo:  727.jpg  Category: horses  Quantidade:  43 / 100
# Extraindo:  743.jpg  Category: horses  Quantidade:  44 / 100
# Extraindo:  716.jpg  Category: horses  Quantidade:  45 / 100
# Extraindo:  756.jpg  Category: horses  Quantidade:  46 / 100
# Extraindo:  735.jpg  Category: horses  Quantidade:  47 / 100
# Extraindo:  787.jpg  Category: horses  Quantidade:  48 / 100
# Extraindo:  792.jpg  Category: horses  Quantidade:  49 / 100
# Extraindo:  799.jpg  Category: horses  Quantidade:  50 / 100
# Extraindo:  793.jpg  Category: horses  Quantidade:  51 / 100
# Extraindo:  796.jpg  Category: horses  Quantidade:  52 / 100
# Extraindo:  785.jpg  Category: horses  Quantidade:  53 / 100
# Extraindo:  720.jpg  Category: horses  Quantidade:  54 / 100
# Extraindo:  737.jpg  Category: horses  Quantidade:  55 / 100
# Extraindo:  732.jpg  Category: horses  Quantidade:  56 / 100
# Extraindo:  746.jpg  Category: horses  Quantidade:  57 / 100
# Extraindo:  718.jpg  Category: horses  Quantidade:  58 / 100
# Extraindo:  772.jpg  Category: horses  Quantidade:  59 / 100
# Extraindo:  710.jpg  Category: horses  Quantidade:  60 / 100
# Extraindo:  764.jpg  Category: horses  Quantidade:  61 / 100
# Extraindo:  739.jpg  Category: horses  Quantidade:  62 / 100
# Extraindo:  788.jpg  Category: horses  Quantidade:  63 / 100
# Extraindo:  733.jpg  Category: horses  Quantidade:  64 / 100
# Extraindo:  731.jpg  Category: horses  Quantidade:  65 / 100
# Extraindo:  783.jpg  Category: horses  Quantidade:  66 / 100
# Extraindo:  779.jpg  Category: horses  Quantidade:  67 / 100
# Extraindo:  747.jpg  Category: horses  Quantidade:  68 / 100
# Extraindo:  759.jpg  Category: horses  Quantidade:  69 / 100
# Extraindo:  798.jpg  Category: horses  Quantidade:  70 / 100
# Extraindo:  744.jpg  Category: horses  Quantidade:  71 / 100
# Extraindo:  714.jpg  Category: horses  Quantidade:  72 / 100
# Extraindo:  742.jpg  Category: horses  Quantidade:  73 / 100
# Extraindo:  782.jpg  Category: horses  Quantidade:  74 / 100
# Extraindo:  741.jpg  Category: horses  Quantidade:  75 / 100
# Extraindo:  738.jpg  Category: horses  Quantidade:  76 / 100
# Extraindo:  765.jpg  Category: horses  Quantidade:  77 / 100
# Extraindo:  790.jpg  Category: horses  Quantidade:  78 / 100
# Extraindo:  781.jpg  Category: horses  Quantidade:  79 / 100
# Extraindo:  776.jpg  Category: horses  Quantidade:  80 / 100
# Extraindo:  749.jpg  Category: horses  Quantidade:  81 / 100
# Extraindo:  766.jpg  Category: horses  Quantidade:  82 / 100
# Extraindo:  715.jpg  Category: horses  Quantidade:  83 / 100
# Extraindo:  745.jpg  Category: horses  Quantidade:  84 / 100
# Extraindo:  753.jpg  Category: horses  Quantidade:  85 / 100
# Extraindo:  725.jpg  Category: horses  Quantidade:  86 / 100
# Extraindo:  768.jpg  Category: horses  Quantidade:  87 / 100
# Extraindo:  734.jpg  Category: horses  Quantidade:  88 / 100
# Extraindo:  748.jpg  Category: horses  Quantidade:  89 / 100
# Extraindo:  763.jpg  Category: horses  Quantidade:  90 / 100
# Extraindo:  754.jpg  Category: horses  Quantidade:  91 / 100
# Extraindo:  780.jpg  Category: horses  Quantidade:  92 / 100
# Extraindo:  730.jpg  Category: horses  Quantidade:  93 / 100
# Extraindo:  726.jpg  Category: horses  Quantidade:  94 / 100
# Extraindo:  729.jpg  Category: horses  Quantidade:  95 / 100
# Extraindo:  751.jpg  Category: horses  Quantidade:  96 / 100
# Extraindo:  775.jpg  Category: horses  Quantidade:  97 / 100
# Extraindo:  778.jpg  Category: horses  Quantidade:  98 / 100
# Extraindo:  712.jpg  Category: horses  Quantidade:  99 / 100
# Extraindo:  432.jpg  Category: dinosaurs  Quantidade:  0 / 100
# Extraindo:  448.jpg  Category: dinosaurs  Quantidade:  1 / 100
# Extraindo:  442.jpg  Category: dinosaurs  Quantidade:  2 / 100
# Extraindo:  425.jpg  Category: dinosaurs  Quantidade:  3 / 100
# Extraindo:  456.jpg  Category: dinosaurs  Quantidade:  4 / 100
# Extraindo:  403.jpg  Category: dinosaurs  Quantidade:  5 / 100
# Extraindo:  427.jpg  Category: dinosaurs  Quantidade:  6 / 100
# Extraindo:  431.jpg  Category: dinosaurs  Quantidade:  7 / 100
# Extraindo:  429.jpg  Category: dinosaurs  Quantidade:  8 / 100
# Extraindo:  411.jpg  Category: dinosaurs  Quantidade:  9 / 100
# Extraindo:  401.jpg  Category: dinosaurs  Quantidade:  10 / 100
# Extraindo:  417.jpg  Category: dinosaurs  Quantidade:  11 / 100
# Extraindo:  415.jpg  Category: dinosaurs  Quantidade:  12 / 100
# Extraindo:  433.jpg  Category: dinosaurs  Quantidade:  13 / 100
# Extraindo:  405.jpg  Category: dinosaurs  Quantidade:  14 / 100
# Extraindo:  493.jpg  Category: dinosaurs  Quantidade:  15 / 100
# Extraindo:  483.jpg  Category: dinosaurs  Quantidade:  16 / 100
# Extraindo:  449.jpg  Category: dinosaurs  Quantidade:  17 / 100
# Extraindo:  486.jpg  Category: dinosaurs  Quantidade:  18 / 100
# Extraindo:  434.jpg  Category: dinosaurs  Quantidade:  19 / 100
# Extraindo:  440.jpg  Category: dinosaurs  Quantidade:  20 / 100
# Extraindo:  491.jpg  Category: dinosaurs  Quantidade:  21 / 100
# Extraindo:  482.jpg  Category: dinosaurs  Quantidade:  22 / 100
# Extraindo:  474.jpg  Category: dinosaurs  Quantidade:  23 / 100
# ...
# Extraindo:  421.jpg  Category: dinosaurs  Quantidade:  41 / 100
# Extraindo:  463.jpg  Category: dinosaurs  Quantidade:  42 / 100
# Extraindo:  498.jpg  Category: dinosaurs  Quantidade:  43 / 100
# Extraindo:  435.jpg  Category: dinosaurs  Quantidade:  44 / 100
# Extraindo:  430.jpg  Category: dinosaurs  Quantidade:  45 / 100
# Extraindo:  404.jpg  Category: dinosaurs  Quantidade:  46 / 100
# Extraindo:  461.jpg  Category: dinosaurs  Quantidade:  47 / 100
# Extraindo:  406.jpg  Category: dinosaurs  Quantidade:  48 / 100
# Extraindo:  454.jpg  Category: dinosaurs  Quantidade:  49 / 100
# Extraindo:  479.jpg  Category: dinosaurs  Quantidade:  50 / 100
# Extraindo:  402.jpg  Category: dinosaurs  Quantidade:  51 / 100
# Extraindo:  436.jpg  Category: dinosaurs  Quantidade:  52 / 100
# Extraindo:  496.jpg  Category: dinosaurs  Quantidade:  53 / 100
# Extraindo:  475.jpg  Category: dinosaurs  Quantidade:  54 / 100
# Extraindo:  464.jpg  Category: dinosaurs  Quantidade:  55 / 100
# Extraindo:  460.jpg  Category: dinosaurs  Quantidade:  56 / 100
# Extraindo:  453.jpg  Category: dinosaurs  Quantidade:  57 / 100
# Extraindo:  495.jpg  Category: dinosaurs  Quantidade:  58 / 100
# Extraindo:  481.jpg  Category: dinosaurs  Quantidade:  59 / 100
# Extraindo:  467.jpg  Category: dinosaurs  Quantidade:  60 / 100
# Extraindo:  407.jpg  Category: dinosaurs  Quantidade:  61 / 100
# Extraindo:  497.jpg  Category: dinosaurs  Quantidade:  62 / 100
# Extraindo:  438.jpg  Category: dinosaurs  Quantidade:  63 / 100
# Extraindo:  489.jpg  Category: dinosaurs  Quantidade:  64 / 100
# Extraindo:  416.jpg  Category: dinosaurs  Quantidade:  65 / 100
# Extraindo:  418.jpg  Category: dinosaurs  Quantidade:  66 / 100
# Extraindo:  450.jpg  Category: dinosaurs  Quantidade:  67 / 100
# Extraindo:  485.jpg  Category: dinosaurs  Quantidade:  68 / 100
# Extraindo:  437.jpg  Category: dinosaurs  Quantidade:  69 / 100
# Extraindo:  471.jpg  Category: dinosaurs  Quantidade:  70 / 100
# Extraindo:  466.jpg  Category: dinosaurs  Quantidade:  71 / 100
# Extraindo:  400.jpg  Category: dinosaurs  Quantidade:  72 / 100
# Extraindo:  419.jpg  Category: dinosaurs  Quantidade:  73 / 100
# Extraindo:  409.jpg  Category: dinosaurs  Quantidade:  74 / 100
# Extraindo:  477.jpg  Category: dinosaurs  Quantidade:  75 / 100
# Extraindo:  422.jpg  Category: dinosaurs  Quantidade:  76 / 100
# Extraindo:  487.jpg  Category: dinosaurs  Quantidade:  77 / 100
# Extraindo:  473.jpg  Category: dinosaurs  Quantidade:  78 / 100
# Extraindo:  492.jpg  Category: dinosaurs  Quantidade:  79 / 100
# Extraindo:  472.jpg  Category: dinosaurs  Quantidade:  80 / 100
# Extraindo:  439.jpg  Category: dinosaurs  Quantidade:  81 / 100
# Extraindo:  443.jpg  Category: dinosaurs  Quantidade:  82 / 100
# Extraindo:  480.jpg  Category: dinosaurs  Quantidade:  83 / 100
# Extraindo:  490.jpg  Category: dinosaurs  Quantidade:  84 / 100
# Extraindo:  446.jpg  Category: dinosaurs  Quantidade:  85 / 100
# Extraindo:  441.jpg  Category: dinosaurs  Quantidade:  86 / 100
# Extraindo:  470.jpg  Category: dinosaurs  Quantidade:  87 / 100
# Extraindo:  476.jpg  Category: dinosaurs  Quantidade:  88 / 100
# Extraindo:  424.jpg  Category: dinosaurs  Quantidade:  89 / 100
# Extraindo:  499.jpg  Category: dinosaurs  Quantidade:  90 / 100
# Extraindo:  451.jpg  Category: dinosaurs  Quantidade:  91 / 100
# Extraindo:  469.jpg  Category: dinosaurs  Quantidade:  92 / 100
# Extraindo:  468.jpg  Category: dinosaurs  Quantidade:  93 / 100
# Extraindo:  445.jpg  Category: dinosaurs  Quantidade:  94 / 100
# Extraindo:  410.jpg  Category: dinosaurs  Quantidade:  95 / 100
# Extraindo:  452.jpg  Category: dinosaurs  Quantidade:  96 / 100
# Extraindo:  458.jpg  Category: dinosaurs  Quantidade:  97 / 100
# Extraindo:  478.jpg  Category: dinosaurs  Quantidade:  98 / 100
# Extraindo:  414.jpg  Category: dinosaurs  Quantidade:  99 / 100
# Extraindo:  508.jpg  Category: elephants  Quantidade:  0 / 100
# Extraindo:  515.jpg  Category: elephants  Quantidade:  1 / 100
# Extraindo:  514.jpg  Category: elephants  Quantidade:  2 / 100
# Extraindo:  501.jpg  Category: elephants  Quantidade:  3 / 100
# Extraindo:  500.jpg  Category: elephants  Quantidade:  4 / 100
# Extraindo:  503.jpg  Category: elephants  Quantidade:  5 / 100
# Extraindo:  512.jpg  Category: elephants  Quantidade:  6 / 100
# Extraindo:  505.jpg  Category: elephants  Quantidade:  7 / 100
# Extraindo:  513.jpg  Category: elephants  Quantidade:  8 / 100
# Extraindo:  524.jpg  Category: elephants  Quantidade:  9 / 100
# Extraindo:  506.jpg  Category: elephants  Quantidade:  10 / 100
# Extraindo:  525.jpg  Category: elephants  Quantidade:  11 / 100
# Extraindo:  507.jpg  Category: elephants  Quantidade:  12 / 100
# Extraindo:  511.jpg  Category: elephants  Quantidade:  13 / 100
# Extraindo:  504.jpg  Category: elephants  Quantidade:  14 / 100
# Extraindo:  520.jpg  Category: elephants  Quantidade:  15 / 100
# Extraindo:  522.jpg  Category: elephants  Quantidade:  16 / 100
# Extraindo:  519.jpg  Category: elephants  Quantidade:  17 / 100
# Extraindo:  510.jpg  Category: elephants  Quantidade:  18 / 100
# Extraindo:  516.jpg  Category: elephants  Quantidade:  19 / 100
# Extraindo:  517.jpg  Category: elephants  Quantidade:  20 / 100
# Extraindo:  521.jpg  Category: elephants  Quantidade:  21 / 100
# Extraindo:  518.jpg  Category: elephants  Quantidade:  22 / 100
# Extraindo:  523.jpg  Category: elephants  Quantidade:  23 / 100
# Extraindo:  509.jpg  Category: elephants  Quantidade:  24 / 100
# Extraindo:  502.jpg  Category: elephants  Quantidade:  25 / 100
# Extraindo:  598.jpg  Category: elephants  Quantidade:  26 / 100
# Extraindo:  546.jpg  Category: elephants  Quantidade:  27 / 100
# Extraindo:  583.jpg  Category: elephants  Quantidade:  28 / 100
# Extraindo:  591.jpg  Category: elephants  Quantidade:  29 / 100
# Extraindo:  567.jpg  Category: elephants  Quantidade:  30 / 100
# Extraindo:  586.jpg  Category: elephants  Quantidade:  31 / 100
# Extraindo:  553.jpg  Category: elephants  Quantidade:  32 / 100
# Extraindo:  549.jpg  Category: elephants  Quantidade:  33 / 100
# Extraindo:  544.jpg  Category: elephants  Quantidade:  34 / 100
# Extraindo:  584.jpg  Category: elephants  Quantidade:  35 / 100
# Extraindo:  581.jpg  Category: elephants  Quantidade:  36 / 100
# Extraindo:  539.jpg  Category: elephants  Quantidade:  37 / 100
# Extraindo:  582.jpg  Category: elephants  Quantidade:  38 / 100
# Extraindo:  543.jpg  Category: elephants  Quantidade:  39 / 100
# Extraindo:  592.jpg  Category: elephants  Quantidade:  40 / 100
# Extraindo:  580.jpg  Category: elephants  Quantidade:  41 / 100
# Extraindo:  577.jpg  Category: elephants  Quantidade:  42 / 100
# Extraindo:  531.jpg  Category: elephants  Quantidade:  43 / 100
# Extraindo:  537.jpg  Category: elephants  Quantidade:  44 / 100
# Extraindo:  578.jpg  Category: elephants  Quantidade:  45 / 100
# Extraindo:  561.jpg  Category: elephants  Quantidade:  46 / 100
# Extraindo:  594.jpg  Category: elephants  Quantidade:  47 / 100
# Extraindo:  541.jpg  Category: elephants  Quantidade:  48 / 100
# Extraindo:  527.jpg  Category: elephants  Quantidade:  49 / 100
# Extraindo:  538.jpg  Category: elephants  Quantidade:  50 / 100
# Extraindo:  550.jpg  Category: elephants  Quantidade:  51 / 100
# Extraindo:  545.jpg  Category: elephants  Quantidade:  52 / 100
# Extraindo:  573.jpg  Category: elephants  Quantidade:  53 / 100
# Extraindo:  568.jpg  Category: elephants  Quantidade:  54 / 100
# Extraindo:  599.jpg  Category: elephants  Quantidade:  55 / 100
# Extraindo:  562.jpg  Category: elephants  Quantidade:  56 / 100
# Extraindo:  532.jpg  Category: elephants  Quantidade:  57 / 100
# Extraindo:  540.jpg  Category: elephants  Quantidade:  58 / 100
# Extraindo:  575.jpg  Category: elephants  Quantidade:  59 / 100
# Extraindo:  526.jpg  Category: elephants  Quantidade:  60 / 100
# Extraindo:  564.jpg  Category: elephants  Quantidade:  61 / 100
# Extraindo:  571.jpg  Category: elephants  Quantidade:  62 / 100
# Extraindo:  596.jpg  Category: elephants  Quantidade:  63 / 100
# Extraindo:  555.jpg  Category: elephants  Quantidade:  64 / 100
# Extraindo:  597.jpg  Category: elephants  Quantidade:  65 / 100
# Extraindo:  557.jpg  Category: elephants  Quantidade:  66 / 100
# Extraindo:  559.jpg  Category: elephants  Quantidade:  67 / 100
# Extraindo:  585.jpg  Category: elephants  Quantidade:  68 / 100
# Extraindo:  589.jpg  Category: elephants  Quantidade:  69 / 100
# Extraindo:  533.jpg  Category: elephants  Quantidade:  70 / 100
# Extraindo:  595.jpg  Category: elephants  Quantidade:  71 / 100
# Extraindo:  554.jpg  Category: elephants  Quantidade:  72 / 100
# Extraindo:  569.jpg  Category: elephants  Quantidade:  73 / 100
# Extraindo:  535.jpg  Category: elephants  Quantidade:  74 / 100
# Extraindo:  587.jpg  Category: elephants  Quantidade:  75 / 100
# Extraindo:  576.jpg  Category: elephants  Quantidade:  76 / 100
# Extraindo:  563.jpg  Category: elephants  Quantidade:  77 / 100
# Extraindo:  572.jpg  Category: elephants  Quantidade:  78 / 100
# Extraindo:  552.jpg  Category: elephants  Quantidade:  79 / 100
# Extraindo:  547.jpg  Category: elephants  Quantidade:  80 / 100
# Extraindo:  556.jpg  Category: elephants  Quantidade:  81 / 100
# Extraindo:  551.jpg  Category: elephants  Quantidade:  82 / 100
# Extraindo:  590.jpg  Category: elephants  Quantidade:  83 / 100
# Extraindo:  566.jpg  Category: elephants  Quantidade:  84 / 100
# Extraindo:  530.jpg  Category: elephants  Quantidade:  85 / 100
# Extraindo:  593.jpg  Category: elephants  Quantidade:  86 / 100
# Extraindo:  579.jpg  Category: elephants  Quantidade:  87 / 100
# Extraindo:  542.jpg  Category: elephants  Quantidade:  88 / 100
# Extraindo:  529.jpg  Category: elephants  Quantidade:  89 / 100
# Extraindo:  534.jpg  Category: elephants  Quantidade:  90 / 100
# Extraindo:  528.jpg  Category: elephants  Quantidade:  91 / 100
# Extraindo:  548.jpg  Category: elephants  Quantidade:  92 / 100
# Extraindo:  558.jpg  Category: elephants  Quantidade:  93 / 100
# Extraindo:  536.jpg  Category: elephants  Quantidade:  94 / 100
# Extraindo:  588.jpg  Category: elephants  Quantidade:  95 / 100
# Extraindo:  574.jpg  Category: elephants  Quantidade:  96 / 100
# Extraindo:  570.jpg  Category: elephants  Quantidade:  97 / 100
# Extraindo:  565.jpg  Category: elephants  Quantidade:  98 / 100
# Extraindo:  560.jpg  Category: elephants  Quantidade:  99 / 100
# Extraindo:  352.jpg  Category: bus  Quantidade:  0 / 100
# Extraindo:  368.jpg  Category: bus  Quantidade:  1 / 100
# Extraindo:  345.jpg  Category: bus  Quantidade:  2 / 100
# Extraindo:  377.jpg  Category: bus  Quantidade:  3 / 100
# Extraindo:  340.jpg  Category: bus  Quantidade:  4 / 100
# Extraindo:  395.jpg  Category: bus  Quantidade:  5 / 100
# Extraindo:  310.jpg  Category: bus  Quantidade:  6 / 100
# Extraindo:  328.jpg  Category: bus  Quantidade:  7 / 100
# Extraindo:  329.jpg  Category: bus  Quantidade:  8 / 100
# Extraindo:  353.jpg  Category: bus  Quantidade:  9 / 100
# Extraindo:  331.jpg  Category: bus  Quantidade:  10 / 100
# Extraindo:  301.jpg  Category: bus  Quantidade:  11 / 100
# Extraindo:  373.jpg  Category: bus  Quantidade:  12 / 100
# Extraindo:  376.jpg  Category: bus  Quantidade:  13 / 100
# Extraindo:  315.jpg  Category: bus  Quantidade:  14 / 100
# Extraindo:  365.jpg  Category: bus  Quantidade:  15 / 100
# Extraindo:  324.jpg  Category: bus  Quantidade:  16 / 100
# Extraindo:  337.jpg  Category: bus  Quantidade:  17 / 100
# Extraindo:  343.jpg  Category: bus  Quantidade:  18 / 100
# Extraindo:  378.jpg  Category: bus  Quantidade:  19 / 100
# Extraindo:  333.jpg  Category: bus  Quantidade:  20 / 100
# Extraindo:  350.jpg  Category: bus  Quantidade:  21 / 100
# Extraindo:  325.jpg  Category: bus  Quantidade:  22 / 100
# Extraindo:  327.jpg  Category: bus  Quantidade:  23 / 100
# Extraindo:  344.jpg  Category: bus  Quantidade:  24 / 100
# Extraindo:  312.jpg  Category: bus  Quantidade:  25 / 100
# Extraindo:  358.jpg  Category: bus  Quantidade:  26 / 100
# Extraindo:  307.jpg  Category: bus  Quantidade:  27 / 100
# Extraindo:  371.jpg  Category: bus  Quantidade:  28 / 100
# Extraindo:  334.jpg  Category: bus  Quantidade:  29 / 100
# Extraindo:  388.jpg  Category: bus  Quantidade:  30 / 100
# Extraindo:  311.jpg  Category: bus  Quantidade:  31 / 100
# Extraindo:  399.jpg  Category: bus  Quantidade:  32 / 100
# Extraindo:  391.jpg  Category: bus  Quantidade:  33 / 100
# Extraindo:  300.jpg  Category: bus  Quantidade:  34 / 100
# Extraindo:  363.jpg  Category: bus  Quantidade:  35 / 100
# Extraindo:  364.jpg  Category: bus  Quantidade:  36 / 100
# Extraindo:  321.jpg  Category: bus  Quantidade:  37 / 100
# Extraindo:  393.jpg  Category: bus  Quantidade:  38 / 100
# Extraindo:  392.jpg  Category: bus  Quantidade:  39 / 100
# Extraindo:  370.jpg  Category: bus  Quantidade:  40 / 100
# Extraindo:  320.jpg  Category: bus  Quantidade:  41 / 100
# Extraindo:  349.jpg  Category: bus  Quantidade:  42 / 100
# Extraindo:  309.jpg  Category: bus  Quantidade:  43 / 100
# Extraindo:  305.jpg  Category: bus  Quantidade:  44 / 100
# Extraindo:  322.jpg  Category: bus  Quantidade:  45 / 100
# Extraindo:  317.jpg  Category: bus  Quantidade:  46 / 100
# Extraindo:  308.jpg  Category: bus  Quantidade:  47 / 100
# Extraindo:  306.jpg  Category: bus  Quantidade:  48 / 100
# Extraindo:  335.jpg  Category: bus  Quantidade:  49 / 100
# Extraindo:  339.jpg  Category: bus  Quantidade:  50 / 100
# Extraindo:  347.jpg  Category: bus  Quantidade:  51 / 100
# Extraindo:  336.jpg  Category: bus  Quantidade:  52 / 100
# Extraindo:  385.jpg  Category: bus  Quantidade:  53 / 100
# Extraindo:  387.jpg  Category: bus  Quantidade:  54 / 100
# Extraindo:  348.jpg  Category: bus  Quantidade:  55 / 100
# Extraindo:  360.jpg  Category: bus  Quantidade:  56 / 100
# Extraindo:  362.jpg  Category: bus  Quantidade:  57 / 100
# Extraindo:  342.jpg  Category: bus  Quantidade:  58 / 100
# Extraindo:  369.jpg  Category: bus  Quantidade:  59 / 100
# Extraindo:  356.jpg  Category: bus  Quantidade:  60 / 100
# Extraindo:  341.jpg  Category: bus  Quantidade:  61 / 100
# Extraindo:  357.jpg  Category: bus  Quantidade:  62 / 100
# Extraindo:  383.jpg  Category: bus  Quantidade:  63 / 100
# Extraindo:  372.jpg  Category: bus  Quantidade:  64 / 100
# Extraindo:  323.jpg  Category: bus  Quantidade:  65 / 100
# Extraindo:  398.jpg  Category: bus  Quantidade:  66 / 100
# Extraindo:  304.jpg  Category: bus  Quantidade:  67 / 100
# Extraindo:  386.jpg  Category: bus  Quantidade:  68 / 100
# Extraindo:  326.jpg  Category: bus  Quantidade:  69 / 100
# Extraindo:  303.jpg  Category: bus  Quantidade:  70 / 100
# Extraindo:  319.jpg  Category: bus  Quantidade:  71 / 100
# Extraindo:  330.jpg  Category: bus  Quantidade:  72 / 100
# Extraindo:  354.jpg  Category: bus  Quantidade:  73 / 100
# Extraindo:  397.jpg  Category: bus  Quantidade:  74 / 100
# Extraindo:  302.jpg  Category: bus  Quantidade:  75 / 100
# Extraindo:  379.jpg  Category: bus  Quantidade:  76 / 100
# Extraindo:  367.jpg  Category: bus  Quantidade:  77 / 100
# Extraindo:  355.jpg  Category: bus  Quantidade:  78 / 100
# Extraindo:  381.jpg  Category: bus  Quantidade:  79 / 100
# Extraindo:  366.jpg  Category: bus  Quantidade:  80 / 100
# Extraindo:  382.jpg  Category: bus  Quantidade:  81 / 100
# Extraindo:  389.jpg  Category: bus  Quantidade:  82 / 100
# Extraindo:  394.jpg  Category: bus  Quantidade:  83 / 100
# Extraindo:  375.jpg  Category: bus  Quantidade:  84 / 100
# Extraindo:  346.jpg  Category: bus  Quantidade:  85 / 100
# Extraindo:  374.jpg  Category: bus  Quantidade:  86 / 100
# Extraindo:  316.jpg  Category: bus  Quantidade:  87 / 100
# Extraindo:  390.jpg  Category: bus  Quantidade:  88 / 100
# Extraindo:  332.jpg  Category: bus  Quantidade:  89 / 100
# Extraindo:  361.jpg  Category: bus  Quantidade:  90 / 100
# Extraindo:  396.jpg  Category: bus  Quantidade:  91 / 100
# Extraindo:  384.jpg  Category: bus  Quantidade:  92 / 100
# Extraindo:  359.jpg  Category: bus  Quantidade:  93 / 100
# Extraindo:  380.jpg  Category: bus  Quantidade:  94 / 100
# Extraindo:  318.jpg  Category: bus  Quantidade:  95 / 100
# Extraindo:  351.jpg  Category: bus  Quantidade:  96 / 100
# Extraindo:  313.jpg  Category: bus  Quantidade:  97 / 100
# Extraindo:  314.jpg  Category: bus  Quantidade:  98 / 100
# Extraindo:  338.jpg  Category: bus  Quantidade:  99 / 100
# []

# %%
len(dataset_files)
# Out:
# 1000

# %%
df_data['file'] = dataset_files
df_data = df_data.rename(columns={32: 'category'})
df_data
# Out:
#            0       1       2       3        4       5       6       7       8  \
# 0      574.0  2236.0  4637.0  3915.0   3379.0  2639.0  2625.0  2977.0  3028.0
# 1     1081.0  8599.0  9969.0  9312.0   7402.0  6416.0  6238.0  5939.0  5444.0
# 2      708.0  6124.0  6721.0  5634.0   4761.0  4828.0  4520.0  5116.0  5312.0
# 3     1836.0  7185.0  7288.0  6203.0   4913.0  4638.0  4488.0  4612.0  4571.0
# 4      474.0  5308.0  5365.0  5973.0   4633.0  3769.0  3831.0  4145.0  5076.0
# ..       ...     ...     ...     ...      ...     ...     ...     ...     ...
# 995   7660.0  9472.0  5368.0  3287.0   2762.0  2396.0  2423.0  2674.0  3820.0
# 996  19849.0  9179.0  6128.0  4480.0   3345.0  2730.0  2523.0  2446.0  2176.0
# 997   8085.0  5542.0  4570.0  8360.0   5129.0  3658.0  2843.0  2523.0  2832.0
# 998   3682.0  6198.0  5449.0  7251.0  10311.0  9382.0  6727.0  5500.0  3976.0
# 999   4112.0  2897.0  1413.0  1849.0   2183.0  2781.0  3287.0  3344.0  3576.0
#
#           9  ...      24      25      26      27      28     29     30    31  \
# 0    3587.0  ...  1909.0  2305.0  2723.0  3589.0  2642.0   34.0    0.0   0.0
# 1    5003.0  ...   668.0   678.0   606.0   476.0   642.0  178.0    6.0   0.0
# 2    4768.0  ...   754.0  1242.0  2156.0  2187.0  1388.0  289.0   30.0   2.0
# 3    4341.0  ...  2230.0  1281.0  1192.0  1957.0  2623.0  295.0   22.0   1.0
# 4    6648.0  ...   884.0   782.0   595.0   424.0   203.0   36.0    9.0   0.0
# ..      ...  ...     ...     ...     ...     ...     ...    ...    ...   ...
# 995  5185.0  ...   888.0  1782.0   402.0   329.0   470.0  198.0   88.0  25.0
# 996  2026.0  ...   463.0   632.0  1184.0  5786.0  2825.0  904.0  254.0  31.0
# 997  2357.0  ...  5892.0  6448.0  4347.0  2595.0  1373.0  535.0  129.0  20.0
# 998  2508.0  ...  2282.0  3116.0  1186.0  1480.0  2163.0  571.0  190.0   8.0
# 999  3315.0  ...   407.0   351.0   585.0  1688.0  2146.0  549.0  153.0  29.0
#
#                           category                                file
# 0    peolpe_and_villages_in_Africa  peolpe_and_villages_in_Africa3.jpg
# 1    peolpe_and_villages_in_Africa  peolpe_and_villages_in_Africa6.jpg
# 2    peolpe_and_villages_in_Africa  peolpe_and_villages_in_Africa9.jpg
# 3    peolpe_and_villages_in_Africa  peolpe_and_villages_in_Africa2.jpg
# 4    peolpe_and_villages_in_Africa  peolpe_and_villages_in_Africa1.jpg
# ..                             ...                                 ...
# 995                            bus                          bus318.jpg
# 996                            bus                          bus351.jpg
# 997                            bus                          bus313.jpg
# 998                            bus                          bus314.jpg
# 999                            bus                          bus338.jpg
#
# [1000 rows x 34 columns]

# %%
output_path = "OUTPUT_PATH/name_dataset.csv"
df_data.to_csv(output_path, index=False)
